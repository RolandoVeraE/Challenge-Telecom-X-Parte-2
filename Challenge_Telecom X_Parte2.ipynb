# %% [markdown]
# #**CHALLENGE TELECOM X PARTE 2**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
datos = pd.read_csv('/content/datos_telecom_tratados.csv')

# %%
datos
# Out:
#       customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     0002 orfbo      0  female              0        1           1       9
# 1     0003 mknfe      0    male              0        0           0       9
# 2     0004 tlhlj      1    male              0        0           0       4
# 3     0011 igkff      1    male              1        1           0      13
# 4     0013 exchz      1  female              1        1           0       3
# ...          ...    ...     ...            ...      ...         ...     ...
# 7038  9987 lutyd      0  female              0        0           0      13
# 7039  9992 rramn      1    male              0        1           0      22
# 7040  9992 ujoel      0    male              0        0           0       2
# 7041  9993 lhieb      0    male              0        1           1      67
# 7042  9995 hotoh      0    male              0        1           1      63
#
#       PhoneService  MultipleLines InternetService  ...  DeviceProtection  \
# 0                1              0             dsl  ...                 0
# 1                1              1             dsl  ...                 0
# 2                1              0     fiber optic  ...                 1
# 3                1              0     fiber optic  ...                 1
# 4                1              0     fiber optic  ...                 0
# ...            ...            ...             ...  ...               ...
# 7038             1              0             dsl  ...                 0
# 7039             1              1     fiber optic  ...                 0
# 7040             1              0             dsl  ...                 0
# 7041             1              0             dsl  ...                 1
# 7042             0              0             dsl  ...                 1
#
#       TechSupport  StreamingTV  StreamingMovies        Contract  \
# 0               1            1                0        one year
# 1               0            0                1  month to month
# 2               0            0                0  month to month
# 3               0            1                1  month to month
# 4               1            1                0  month to month
# ...           ...          ...              ...             ...
# 7038            1            0                0        one year
# 7039            0            0                1  month to month
# 7040            0            0                0  month to month
# 7041            1            0                1        two year
# 7042            0            1                1        two year
#
#       PaperlessBilling     PaymentMethod  ChargesMonthly ChargesTotal  \
# 0                    1      mailed check           65.60       593.30
# 1                    0      mailed check           59.90       542.40
# 2                    1  electronic check           73.90       280.85
# 3                    1  electronic check           98.00      1237.85
# 4                    1      mailed check           83.90       267.40
# ...                ...               ...             ...          ...
# 7038                 0      mailed check           55.15       742.90
# 7039                 1  electronic check           85.10      1873.70
# 7040                 1      mailed check           50.30        92.75
# 7041                 0      mailed check           67.85      4627.65
# 7042                 0  electronic check           59.00      3707.60
#
#       cuentas_diarias
# 0            2.186667
# 1            1.996667
# 2            2.463333
# 3            3.266667
# 4            2.796667
# ...               ...
# 7038         1.838333
# 7039         2.836667
# 7040         1.676667
# 7041         2.261667
# 7042         1.966667
#
# [7043 rows x 22 columns]

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Churn             7043 non-null   int64
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   int64
#  4   Partner           7043 non-null   int64
#  5   Dependents        7043 non-null   int64
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   int64
#  8   MultipleLines     7043 non-null   int64
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   int64
#  11  OnlineBackup      7043 non-null   int64
#  12  DeviceProtection  7043 non-null   int64
#  13  TechSupport       7043 non-null   int64
#  14  StreamingTV       7043 non-null   int64
#  15  StreamingMovies   7043 non-null   int64
#  16  Contract          7043 non-null   object
#  17  PaperlessBilling  7043 non-null   int64
#  18  PaymentMethod     7043 non-null   object
#  19  ChargesMonthly    7043 non-null   float64
#  20  ChargesTotal      7032 non-null   float64
#  21  cuentas_diarias   7043 non-null   float64
# dtypes: float64(3), int64(14), object(5)
# memory usage: 1.2+ MB

# %%
datos.describe()
# Out:
#              Churn  SeniorCitizen      Partner   Dependents       tenure  \
# count  7043.000000    7043.000000  7043.000000  7043.000000  7043.000000
# mean      0.265370       0.162147     0.483033     0.299588    32.371149
# std       0.441561       0.368612     0.499748     0.458110    24.559481
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000     9.000000
# 50%       0.000000       0.000000     0.000000     0.000000    29.000000
# 75%       1.000000       0.000000     1.000000     1.000000    55.000000
# max       1.000000       1.000000     1.000000     1.000000    72.000000
#
#        PhoneService  MultipleLines  OnlineSecurity  OnlineBackup  \
# count   7043.000000    7043.000000     7043.000000   7043.000000
# mean       0.903166       0.421837        0.286668      0.344881
# std        0.295752       0.493888        0.452237      0.475363
# min        0.000000       0.000000        0.000000      0.000000
# 25%        1.000000       0.000000        0.000000      0.000000
# 50%        1.000000       0.000000        0.000000      0.000000
# 75%        1.000000       1.000000        1.000000      1.000000
# max        1.000000       1.000000        1.000000      1.000000
#
#        DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# count       7043.000000  7043.000000  7043.000000      7043.000000
# mean           0.343888     0.290217     0.384353         0.387903
# std            0.475038     0.453895     0.486477         0.487307
# min            0.000000     0.000000     0.000000         0.000000
# 25%            0.000000     0.000000     0.000000         0.000000
# 50%            0.000000     0.000000     0.000000         0.000000
# 75%            1.000000     1.000000     1.000000         1.000000
# max            1.000000     1.000000     1.000000         1.000000
#
#        PaperlessBilling  ChargesMonthly  ChargesTotal  cuentas_diarias
# count       7043.000000     7043.000000   7032.000000      7043.000000
# mean           0.592219       64.761692   2283.300441         2.158723
# std            0.491457       30.090047   2266.771362         1.003002
# min            0.000000       18.250000     18.800000         0.608333
# 25%            0.000000       35.500000    401.450000         1.183333
# 50%            1.000000       70.350000   1397.475000         2.345000
# 75%            1.000000       89.850000   3794.737500         2.995000
# max            1.000000      118.750000   8684.800000         3.958333

# %%
#veremos nuestras variables categóricas
datos.describe(include='O') # letra O mayuscula me va a dar las estadisticas de las variables categóricas
# Out:
#         customerID gender InternetService        Contract     PaymentMethod
# count         7043   7043            7043            7043              7043
# unique        7043      2               3               3                 4
# top     9995 hotoh   male     fiber optic  month to month  electronic check
# freq             1   3555            3096            3875              2365

# %% [markdown]
# ##**Análisis Gráficos de Variables Cuantitativas o Numéricas**

# %% [markdown]
# ###**Distribución del abandono**

# %%
datos.groupby('Churn').value_counts()
# Out:
# Churn  customerID  gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  MultipleLines  InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract        PaperlessBilling  PaymentMethod            ChargesMonthly  ChargesTotal  cuentas_diarias
# 0      0002 orfbo  female  0              1        1           9       1             0              dsl              0               1             0                 1            1            0                one year        1                 mailed check             65.60           593.30        2.186667           1
#        0003 mknfe  male    0              0        0           9       1             1              dsl              0               0             0                 0            0            1                month to month  0                 mailed check             59.90           542.40        1.996667           1
#        0013 mhzwf  female  0              0        1           9       1             0              dsl              0               0             0                 1            1            1                month to month  1                 credit card automatic    69.40           571.45        2.313333           1
#        0013 smeoe  female  1              1        0           71      1             0              fiber optic      1               1             1                 1            1            1                two year        1                 bank transfer automatic  109.70          7904.25       3.656667           1
#        0014 bmaqu  male    0              1        0           63      1             1              fiber optic      1               0             0                 1            0            0                two year        1                 credit card automatic    84.65           5377.80       2.821667           1
#                                                                                                                                                                                                                                                                                                                            ..
# 1      9961 jbnmk  male    1              0        0           21      1             0              fiber optic      0               0             1                 0            1            1                month to month  1                 bank transfer automatic  96.80           2030.30       3.226667           1
#        9965 yokzb  male    1              0        0           9       1             1              fiber optic      0               0             0                 0            0            1                month to month  1                 electronic check         83.85           790.15        2.795000           1
#        9985 mwvix  female  0              0        0           1       1             0              fiber optic      0               0             0                 0            0            0                month to month  1                 mailed check             70.15           70.15         2.338333           1
#        9986 bonce  female  0              0        0           4       1             0              no               0               0             0                 0            0            0                month to month  0                 bank transfer automatic  20.95           85.50         0.698333           1
#        9992 rramn  male    0              1        0           22      1             1              fiber optic      0               0             0                 0            0            1                month to month  1                 electronic check         85.10           1873.70       2.836667           1
# Name: count, Length: 7032, dtype: int64

# %%
# Distribucion de la variable Churn (Abandono)
sns.countplot(data=datos, x='Churn')
plt.title('Distribución del Churn')
plt.xticks([0,1],['No','Si'])
plt.xlabel('Abandonó el Servicio')
plt.ylabel('Cantidad de Clientes')
plt.show()

# %% [markdown]
# La variable dependiente es Churn

# %% [markdown]
# ###**Abandono si es mayor de 65 Años**

# %%
datos.groupby('SeniorCitizen')['Churn'].value_counts()
# Out:
# SeniorCitizen  Churn
# 0              0        4508
#                1        1393
# 1              0         666
#                1         476
# Name: count, dtype: int64

# %%
sns.countplot(x='SeniorCitizen', data=datos,hue='Churn')
plt.title('Mayores de 65 años vs Abandono ')
plt.xlabel('Mayores de 65 años')
plt.xticks([0,1],['Menor de 65 años','Mayor de 65 años'])
plt.ylabel('Cantidad de Abandono')
plt.show()

# %% [markdown]
# El abandono en los mayores de 65 años es relevante, creando soluciones que se ajusten a sus necesidades se puede retener a un cliente que no es muy tecnológico

# %% [markdown]
# ###**Abandono si el cliente tiene pareja**

# %%
datos.groupby('Partner')['Churn'].value_counts()
# Out:
# Partner  Churn
# 0        0        2441
#          1        1200
# 1        0        2733
#          1         669
# Name: count, dtype: int64

# %%
sns.countplot(x='Partner', data=datos,hue='Churn')
plt.title('Cliente tiene Pareja vs Abandono ')
plt.xlabel('Cliente tiene Pareja')
plt.xticks([0,1],['No Tiene Pareja','Tiene Pareja'])
plt.ylabel('Cantidad de Abandono')
plt.show()

# %% [markdown]
# Los clientes que no tienen pareja, tiene más abandono, talvez si conocieramos los rangos de edades de los clientes con pareja, se podría saber si debe a que tienen otras actividades como el deporte o bien si tienen una edad más avanzada, tal vez, los productos y servicios de la empresa no son los adecuados para ellos

# %% [markdown]
# ###**Abandono por Meses de contrato**

# %%
datos.groupby('tenure')['Churn'].value_counts(normalize=True)
# Out:
# tenure  Churn
# 0       0        1.000000
# 1       1        0.619902
#         0        0.380098
# 2       1        0.516807
#         0        0.483193
#                    ...
# 70      1        0.092437
# 71      0        0.964706
#         1        0.035294
# 72      0        0.983425
#         1        0.016575
# Name: proportion, Length: 145, dtype: float64

# %%
sns.histplot(data=datos, x='tenure',kde=True)
# Out:
# <Axes: xlabel='tenure', ylabel='Count'>

# %% [markdown]
# Del grafico podemos decir que tenemos que incentivar los contrato a a largo plazo

# %% [markdown]
# ###**Abandono versus Servicio telefónico**

# %%
datos.groupby('PhoneService')['Churn'].value_counts()
# Out:
# PhoneService  Churn
# 0             0         512
#               1         170
# 1             0        4662
#               1        1699
# Name: count, dtype: int64

# %%
sns.countplot(x='PhoneService', data=datos,hue='Churn')
plt.title('Servicio Telefónico vs Abandono ')
plt.xlabel('Servicio Telefónico')
plt.xticks([0,1],['No Tiene Telefono','Tiene Telefono'])
plt.ylabel('Cantidad de Abandono')
plt.show()

# %% [markdown]
# El abandono en clientes con servicio telefónico es alto. Se tendría que ver la calidad del servicio para bajar el abandono.

# %% [markdown]
# ###**Abandono si tiene multiples líneas**

# %%
datos.groupby('MultipleLines')['Churn'].value_counts()
# Out:
# MultipleLines  Churn
# 0              0        3053
#                1        1019
# 1              0        2121
#                1         850
# Name: count, dtype: int64

# %%
sns.countplot(x='MultipleLines', data=datos,hue='Churn')
plt.title('Multiples Líneas vs Abandono ')
plt.xlabel('Multiples Líneas')
plt.xticks([0,1],['No Tiene Multiples líneas','Tiene Multiples Líneas'],rotation=70)

plt.ylabel('Cantidad de Abandono')
plt.show()

# %% [markdown]
# ###**Abandono si tiene Seguridad OnLine**

# %%
datos.groupby('OnlineSecurity')['Churn'].value_counts()
# Out:
# OnlineSecurity  Churn
# 0               0        3450
#                 1        1574
# 1               0        1724
#                 1         295
# Name: count, dtype: int64

# %%
sns.countplot(x='OnlineSecurity', data=datos,hue='Churn')
plt.title('Seguridad On Line vs Abandono ')
plt.xlabel('Seguridad On Line')
plt.xticks([0,1],['No Tiene Seguridad On Line','Tiene Seguridad On Line'],rotation=70)

plt.ylabel('Cantidad de Abandono')
plt.show()

# %% [markdown]
# El abandono es bajo respecto a la seguridad On Line

# %% [markdown]
# ###**Abandono si tiene Respaldo en Línea**

# %%
datos.groupby('OnlineBackup')['Churn'].value_counts(normalize=True)
# Out:
# OnlineBackup  Churn
# 0             0        0.708279
#               1        0.291721
# 1             0        0.784685
#               1        0.215315
# Name: proportion, dtype: float64

# %%
sns.countplot(x='OnlineBackup', data=datos,hue='Churn')
plt.title('Respaldo On Line vs Abandono ')
plt.xlabel('Respaldo on Line')
plt.xticks([0,1],['No Tiene Respaldo On Line','Tiene Respaldo On Line'],rotation=70)

plt.ylabel('Cantidad de Abandono')
plt.show()

# %% [markdown]
# Los clientes que abandonan y que tiene respaldo On Line es de 21.5% con respecto a los clientes que se quedan y tienen respado on line

# %% [markdown]
# ###**Abandono si tiene Protección de Dispositivos**

# %%
datos.groupby('DeviceProtection')['Churn'].value_counts(normalize=True)
# Out:
# DeviceProtection  Churn
# 0                 0        0.713482
#                   1        0.286518
# 1                 0        0.774979
#                   1        0.225021
# Name: proportion, dtype: float64

# %%
sns.countplot(x='DeviceProtection', data=datos,hue='Churn')
plt.title('Protección de Dispositivo vs Abandono ')
plt.xlabel('Protección de Dispositivo')
plt.xticks([0,1],['No Tiene Protección de Dispositivo','Tiene Protección de Dispositivo'],rotation=70)

plt.ylabel('Cantidad de Abandono')
plt.show()

# %% [markdown]
# El abandono de los clientes que tienen Protección de dispositivos es de 22.5%

# %% [markdown]
# ###**Abandono por Soporte Técnico**

# %%
datos.groupby('TechSupport')['Churn'].value_counts(normalize=True)
# Out:
# TechSupport  Churn
# 0            0        0.688138
#              1        0.311862
# 1            0        0.848337
#              1        0.151663
# Name: proportion, dtype: float64

# %%
sns.countplot(x='TechSupport', data=datos,hue='Churn')
plt.title('Soporte Técnico vs Abandono ')
plt.xlabel('Soporte Técnico')
plt.xticks([0,1],['No Tiene Soporte Técnico','Tiene Soporte Técnico'],rotation=70)

plt.ylabel('Cantidad de Abandono')
plt.show()

# %% [markdown]
# ###**Abandono por StreamingTV**

# %%
datos.groupby('StreamingTV')['Churn'].value_counts(normalize=True)
# Out:
# StreamingTV  Churn
# 0            0        0.756688
#              1        0.243312
# 1            0        0.699298
#              1        0.300702
# Name: proportion, dtype: float64

# %%
sns.countplot(x='StreamingTV', data=datos,hue='Churn')
plt.title('StreamingTV vs Abandono ')
plt.xlabel('StreamingTV')
plt.xticks([0,1],['No Tiene StreamingTV','Tiene StreamingTV'],rotation=70)

plt.ylabel('Cantidad de Abandono')
plt.show()

# %% [markdown]
# El abandono por StreamingTV es del 30%,

# %% [markdown]
# ###**Abandono por StreamingMovies**

# %%
datos.groupby('StreamingMovies')['Churn'].value_counts(normalize=True)
# Out:
# StreamingMovies  Churn
# 0                0        0.756205
#                  1        0.243795
# 1                0        0.700586
#                  1        0.299414
# Name: proportion, dtype: float64

# %%
sns.countplot(x='StreamingMovies', data=datos,hue='Churn')
plt.title('StreamingMovies vs Abandono ')
plt.xlabel('StreamingMovies')
plt.xticks([0,1],['No Tiene StreamingMovies','Tiene StreamingMovies'],rotation=70)

plt.ylabel('Cantidad de Abandono')
plt.show()

# %% [markdown]
# El Abandono por StreamingMovies es del 30%

# %% [markdown]
# ###**Abandono por Cargos Mensuales**

# %%
datos['ChargesMonthly'].unique()
# Out:
# array([65.6 , 59.9 , 73.9 , ..., 91.75, 68.8 , 67.85])

# %%
datos['ChargesMonthly'].nunique()
# Out:
# 1585

# %%
datos.groupby('ChargesMonthly')['Churn'].value_counts(normalize=True)
# Out:
# ChargesMonthly  Churn
# 18.25           0        1.0
# 18.40           0        1.0
# 18.55           0        1.0
# 18.70           0        1.0
# 18.75           0        1.0
#                         ...
# 118.20          0        1.0
# 118.35          1        1.0
# 118.60          0        1.0
# 118.65          0        1.0
# 118.75          0        1.0
# Name: proportion, Length: 2370, dtype: float64

# %%
sns.histplot(data=datos, x='ChargesMonthly',kde=True)
# Out:
# <Axes: xlabel='ChargesMonthly', ylabel='Count'>

# %% [markdown]
# ###**Abandono por cargos Totales**

# %%
datos['ChargesTotal'].unique()
# Out:
# array([ 593.3 ,  542.4 ,  280.85, ...,  742.9 , 4627.65, 3707.6 ])

# %%
datos['ChargesTotal'].nunique()
# Out:
# 6530

# %%
datos.groupby('ChargesTotal')['Churn'].value_counts(normalize=True)
# Out:
# ChargesTotal  Churn
# 18.80         0        1.0
# 18.85         0        0.5
#               1        0.5
# 18.90         0        1.0
# 19.00         0        1.0
#                       ...
# 8564.75       0        1.0
# 8594.40       0        1.0
# 8670.10       0        1.0
# 8672.45       0        1.0
# 8684.80       1        1.0
# Name: proportion, Length: 6697, dtype: float64

# %%
sns.histplot(data=datos, x='ChargesTotal',kde=True)
# Out:
# <Axes: xlabel='ChargesTotal', ylabel='Count'>

# %% [markdown]
# ##**Análisis Gráficos de Variables Cualitativas o Categóricas**

# %% [markdown]
# ###**Abandono Según el Sexo**

# %%
datos.groupby('gender')['Churn'].value_counts(normalize=True)
# Out:
# gender  Churn
# female  0        0.730791
#         1        0.269209
# male    0        0.738397
#         1        0.261603
# Name: proportion, dtype: float64

# %%
sns.countplot(x='gender', data=datos,hue='Churn')
plt.title('Género vs Abandono ')
plt.xlabel('Género')
plt.ylabel('Cantidad de Abandono')
plt.show()

# %% [markdown]
# Podemos concluir que la proporción de abandono de la compañía por sexo es casi la misma, por lo que no influye en el análisis final.Hay que realizar algún tipo de campaña mara bajar el abandono como descuentos, mejora de planes, beneficios entre otros.

# %% [markdown]
# ###**Abandono Versus Servicios de Internet**

# %%
datos['InternetService'].unique()
# Out:
# array(['dsl', 'fiber optic', 'no'], dtype=object)

# %%
abandono_por_servicio = datos.groupby('InternetService')['Churn'].value_counts(normalize=True)
abandono_por_servicio
# Out:
# InternetService  Churn
# dsl              0        0.810409
#                  1        0.189591
# fiber optic      0        0.581072
#                  1        0.418928
# no               0        0.925950
#                  1        0.074050
# Name: proportion, dtype: float64

# %%
sns.countplot(x='InternetService', data=datos,hue='Churn')
plt.title('Servicios de Internet vs Abandono ')
plt.xlabel('Servicios de Internet')
plt.ylabel('Cantidad de Abandono')
plt.show()

# %% [markdown]
# El abandono por servicio de internet es mayor en el servicio de Fibra óptica por que tendraimos que mejorar calidad de ese servicio

# %% [markdown]
# ###**Abandono por tipo de contrato**

# %%
abandono_por_contrato = datos.groupby('Contract')['Churn'].value_counts(normalize=True)
abandono_por_contrato
# Out:
# Contract        Churn
# month to month  0        0.572903
#                 1        0.427097
# one year        0        0.887305
#                 1        0.112695
# two year        0        0.971681
#                 1        0.028319
# Name: proportion, dtype: float64

# %%
datos['Contract'].unique()
# Out:
# array(['one year', 'month to month', 'two year'], dtype=object)

# %%
sns.countplot(x='Contract', data=datos,hue='Churn')
plt.title('Contrato vs Abandono ')
plt.xlabel('Contratos')
plt.ylabel('Cantidad de Abandono')
plt.show()

# %% [markdown]
# El abandono por contrato mes a mes es el que tiene mayor número de abandono por lo que habría fomentar otro tipo de contratos a largo plazo, dando algún tipo de descuento para premiar la permanencia en la empresa

# %% [markdown]
# ###**Abandono por Metodo de Pago**

# %%
abandono_por_tipo_pago = datos.groupby('PaymentMethod')['Churn'].value_counts(normalize=True)
abandono_por_tipo_pago
# Out:
# PaymentMethod            Churn
# bank transfer automatic  0        0.832902
#                          1        0.167098
# credit card automatic    0        0.847569
#                          1        0.152431
# electronic check         0        0.547146
#                          1        0.452854
# mailed check             0        0.808933
#                          1        0.191067
# Name: proportion, dtype: float64

# %%
sns.countplot(x='PaymentMethod', data=datos,hue='Churn')
plt.title('Método de Pago vs Abandono ')
plt.xlabel('Método de Pago')
plt.ylabel('Cantidad de Abandono')
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# El mayor número de abandono es en el tipo de pago electrónico por lo que tendramos que fomentar otro tipo de pago o mejorar la experiencia de pago haciendolo más fácil

# %% [markdown]
# ##**Codificación las variables que no se pudieron transformar en 1 ó 0**

# %%
# creación de una lista con las variables  categoricas
categoricas =['gender','InternetService','Contract','PaymentMethod']

# %%
datos_codificados = pd.get_dummies(data=datos,columns=categoricas,dtype=int)

# %%
datos_codificados.sample(8)
# Out:
#       customerID  Churn  SeniorCitizen  Partner  Dependents  tenure  \
# 4340  6122 ljada      0              0        1           1      70
# 2157  3090 qfuvd      0              0        0           0       1
# 6848  9730 drtmj      0              0        1           0      32
# 2832  4024 csnby      0              0        1           0      72
# 30    0048 lumls      0              0        1           1      37
# 1418  2087 qarey      0              0        1           0      22
# 3163  4537 cibhb      0              0        1           1       9
# 3019  4320 qmlla      0              0        0           0       7
#
#       PhoneService  MultipleLines  OnlineSecurity  OnlineBackup  ...  \
# 4340             1              1               1             1  ...
# 2157             1              0               0             0  ...
# 6848             1              1               1             0  ...
# 2832             1              1               1             1  ...
# 30               1              0               0             0  ...
# 1418             1              0               0             1  ...
# 3163             1              0               0             0  ...
# 3019             1              0               0             0  ...
#
#       InternetService_dsl  InternetService_fiber optic  InternetService_no  \
# 4340                    1                            0                   0
# 2157                    0                            0                   1
# 6848                    1                            0                   0
# 2832                    0                            1                   0
# 30                      0                            1                   0
# 1418                    1                            0                   0
# 3163                    0                            0                   1
# 3019                    1                            0                   0
#
#       Contract_month to month  Contract_one year  Contract_two year  \
# 4340                        0                  0                  1
# 2157                        1                  0                  0
# 6848                        0                  1                  0
# 2832                        0                  0                  1
# 30                          0                  1                  0
# 1418                        1                  0                  0
# 3163                        0                  1                  0
# 3019                        1                  0                  0
#
#       PaymentMethod_bank transfer automatic  \
# 4340                                      0
# 2157                                      0
# 6848                                      0
# 2832                                      1
# 30                                        0
# 1418                                      0
# 3163                                      0
# 3019                                      0
#
#       PaymentMethod_credit card automatic  PaymentMethod_electronic check  \
# 4340                                    1                               0
# 2157                                    1                               0
# 6848                                    1                               0
# 2832                                    0                               0
# 30                                      1                               0
# 1418                                    0                               0
# 3163                                    0                               0
# 3019                                    0                               0
#
#       PaymentMethod_mailed check
# 4340                           0
# 2157                           0
# 6848                           0
# 2832                           0
# 30                             0
# 1418                           1
# 3163                           1
# 3019                           1
#
# [8 rows x 30 columns]

# %%
datos_codificados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 30 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   customerID                             7043 non-null   object
#  1   Churn                                  7043 non-null   int64
#  2   SeniorCitizen                          7043 non-null   int64
#  3   Partner                                7043 non-null   int64
#  4   Dependents                             7043 non-null   int64
#  5   tenure                                 7043 non-null   int64
#  6   PhoneService                           7043 non-null   int64
#  7   MultipleLines                          7043 non-null   int64
#  8   OnlineSecurity                         7043 non-null   int64
#  9   OnlineBackup                           7043 non-null   int64
#  10  DeviceProtection                       7043 non-null   int64
#  11  TechSupport                            7043 non-null   int64
#  12  StreamingTV                            7043 non-null   int64
#  13  StreamingMovies                        7043 non-null   int64
#  14  PaperlessBilling                       7043 non-null   int64
#  15  ChargesMonthly                         7043 non-null   float64
#  16  ChargesTotal                           7032 non-null   float64
#  17  cuentas_diarias                        7043 non-null   float64
#  18  gender_female                          7043 non-null   int64
#  19  gender_male                            7043 non-null   int64
#  20  InternetService_dsl                    7043 non-null   int64
#  21  InternetService_fiber optic            7043 non-null   int64
#  22  InternetService_no                     7043 non-null   int64
#  23  Contract_month to month                7043 non-null   int64
#  24  Contract_one year                      7043 non-null   int64
#  25  Contract_two year                      7043 non-null   int64
#  26  PaymentMethod_bank transfer automatic  7043 non-null   int64
#  27  PaymentMethod_credit card automatic    7043 non-null   int64
#  28  PaymentMethod_electronic check         7043 non-null   int64
#  29  PaymentMethod_mailed check             7043 non-null   int64
# dtypes: float64(3), int64(26), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# ##**Eliminación de Columna Identificador ID**

# %%
df = datos_codificados.drop('customerID',axis=1)

# %%
df.sample(5)
# Out:
#       Churn  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 3238      0              0        1           1      32             1
# 3567      0              0        1           0      65             1
# 3046      1              0        0           0      41             1
# 3278      0              0        0           0      57             1
# 2064      0              0        1           1       7             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 3238              0               0             0                 0  ...
# 3567              1               1             0                 1  ...
# 3046              1               1             1                 1  ...
# 3278              1               0             0                 0  ...
# 2064              0               1             1                 1  ...
#
#       InternetService_dsl  InternetService_fiber optic  InternetService_no  \
# 3238                    0                            0                   1
# 3567                    0                            1                   0
# 3046                    0                            1                   0
# 3278                    0                            1                   0
# 2064                    1                            0                   0
#
#       Contract_month to month  Contract_one year  Contract_two year  \
# 3238                        0                  0                  1
# 3567                        1                  0                  0
# 3046                        1                  0                  0
# 3278                        0                  1                  0
# 2064                        0                  1                  0
#
#       PaymentMethod_bank transfer automatic  \
# 3238                                      0
# 3567                                      0
# 3046                                      1
# 3278                                      0
# 2064                                      0
#
#       PaymentMethod_credit card automatic  PaymentMethod_electronic check  \
# 3238                                    0                               0
# 3567                                    0                               1
# 3046                                    0                               0
# 3278                                    0                               1
# 2064                                    0                               1
#
#       PaymentMethod_mailed check
# 3238                           1
# 3567                           0
# 3046                           0
# 3278                           0
# 2064                           0
#
# [5 rows x 29 columns]

# %% [markdown]
# ##**Distribución de la Frecuencia del Churn o Abandono**

# %%
datos['Churn'].value_counts(normalize=True)
# Out:
# Churn
# 0    0.73463
# 1    0.26537
# Name: proportion, dtype: float64

# %% [markdown]
# Los datos están desbalanceados ya que los clientes que abandonan la empresa es de 26,53% con respecto a total de clientes (7043 clientes totales)

# %%
ax=sns.distplot(datos['Churn'])
ax.figure.set_size_inches(20, 6),
ax.set_title('Distribuición de Frecuencias', fontsize=20)
ax.set_xlabel('Churn', fontsize=16)
ax
# Out:
# /tmp/ipython-input-1478845711.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(datos['Churn'])
# <Axes: title={'center': 'Distribuición de Frecuencias'}, xlabel='Churn', ylabel='Density'>

# %%
sns.histplot(data=datos, x='Churn',kde=True)
# Out:
# <Axes: xlabel='Churn', ylabel='Count'>

# %% [markdown]
# Elegiremos módelos que no son sensibles a las  escalas como Random Forest y Decision Tree. Por lo que no Normalizaremos los datos

# %% [markdown]
# ##**Matriz de Correlación**

# %%
df.corr().round(4)
# Out:
#                                         Churn  SeniorCitizen  Partner  \
# Churn                                  1.0000         0.1509  -0.1504
# SeniorCitizen                          0.1509         1.0000   0.0165
# Partner                               -0.1504         0.0165   1.0000
# Dependents                            -0.1642        -0.2112   0.4527
# tenure                                -0.3522         0.0166   0.3797
# PhoneService                           0.0119         0.0086   0.0177
# MultipleLines                          0.0401         0.1429   0.1421
# OnlineSecurity                        -0.1712        -0.0387   0.1431
# OnlineBackup                          -0.0823         0.0666   0.1415
# DeviceProtection                      -0.0662         0.0594   0.1538
# TechSupport                           -0.1647        -0.0606   0.1200
# StreamingTV                            0.0632         0.1054   0.1247
# StreamingMovies                        0.0614         0.1202   0.1174
# PaperlessBilling                       0.1918         0.1565  -0.0149
# ChargesMonthly                         0.1934         0.2202   0.0968
# ChargesTotal                          -0.1995         0.1024   0.3191
# cuentas_diarias                        0.1934         0.2202   0.0968
# gender_female                          0.0086         0.0019   0.0018
# gender_male                           -0.0086        -0.0019  -0.0018
# InternetService_dsl                   -0.1242        -0.1083  -0.0009
# InternetService_fiber optic            0.3080         0.2553   0.0003
# InternetService_no                    -0.2279        -0.1827   0.0006
# Contract_month to month                0.4051         0.1384  -0.2809
# Contract_one year                     -0.1778        -0.0463   0.0828
# Contract_two year                     -0.3023        -0.1170   0.2481
# PaymentMethod_bank transfer automatic -0.1179        -0.0162   0.1107
# PaymentMethod_credit card automatic   -0.1343        -0.0241   0.0820
# PaymentMethod_electronic check         0.3019         0.1717  -0.0839
# PaymentMethod_mailed check            -0.0917        -0.1535  -0.0951
#
#                                        Dependents  tenure  PhoneService  \
# Churn                                     -0.1642 -0.3522        0.0119
# SeniorCitizen                             -0.2112  0.0166        0.0086
# Partner                                    0.4527  0.3797        0.0177
# Dependents                                 1.0000  0.1597       -0.0018
# tenure                                     0.1597  1.0000        0.0084
# PhoneService                              -0.0018  0.0084        1.0000
# MultipleLines                             -0.0245  0.3319        0.2797
# OnlineSecurity                             0.0810  0.3272       -0.0929
# OnlineBackup                               0.0237  0.3603       -0.0523
# DeviceProtection                           0.0140  0.3607       -0.0712
# TechSupport                                0.0633  0.3242       -0.0963
# StreamingTV                               -0.0166  0.2798       -0.0226
# StreamingMovies                           -0.0397  0.2861       -0.0330
# PaperlessBilling                          -0.1114  0.0062        0.0165
# ChargesMonthly                            -0.1139  0.2479        0.2474
# ChargesTotal                               0.0647  0.8259        0.1130
# cuentas_diarias                           -0.1139  0.2479        0.2474
# gender_female                             -0.0105 -0.0051        0.0065
# gender_male                                0.0105  0.0051       -0.0065
# InternetService_dsl                        0.0520  0.0133       -0.4524
# InternetService_fiber optic               -0.1658  0.0197        0.2900
# InternetService_no                         0.1398 -0.0391        0.1722
# Contract_month to month                   -0.2317 -0.6456       -0.0007
# Contract_one year                          0.0684  0.2026       -0.0028
# Contract_two year                          0.2046  0.5585        0.0035
# PaymentMethod_bank transfer automatic      0.0520  0.2435        0.0076
# PaymentMethod_credit card automatic        0.0603  0.2330       -0.0077
# PaymentMethod_electronic check            -0.1506 -0.2084        0.0031
# PaymentMethod_mailed check                 0.0591 -0.2339       -0.0033
#
#                                        MultipleLines  OnlineSecurity  \
# Churn                                         0.0401         -0.1712
# SeniorCitizen                                 0.1429         -0.0387
# Partner                                       0.1421          0.1431
# Dependents                                   -0.0245          0.0810
# tenure                                        0.3319          0.3272
# PhoneService                                  0.2797         -0.0929
# MultipleLines                                 1.0000          0.0981
# OnlineSecurity                                0.0981          1.0000
# OnlineBackup                                  0.2022          0.2838
# DeviceProtection                              0.2011          0.2754
# TechSupport                                   0.1006          0.3549
# StreamingTV                                   0.2572          0.1762
# StreamingMovies                               0.2588          0.1874
# PaperlessBilling                              0.1635         -0.0036
# ChargesMonthly                                0.4904          0.2966
# ChargesTotal                                  0.4690          0.4126
# cuentas_diarias                               0.4904          0.2966
# gender_female                                 0.0084          0.0170
# gender_male                                  -0.0084         -0.0170
# InternetService_dsl                          -0.1999          0.3213
# InternetService_fiber optic                   0.3661         -0.0307
# InternetService_no                           -0.2106         -0.3334
# Contract_month to month                      -0.0882         -0.2467
# Contract_one year                            -0.0038          0.1002
# Contract_two year                             0.1063          0.1918
# PaymentMethod_bank transfer automatic         0.0755          0.0952
# PaymentMethod_credit card automatic           0.0600          0.1157
# PaymentMethod_electronic check                0.0836         -0.1123
# PaymentMethod_mailed check                   -0.2272         -0.0808
#
#                                        OnlineBackup  DeviceProtection  ...  \
# Churn                                       -0.0823           -0.0662  ...
# SeniorCitizen                                0.0666            0.0594  ...
# Partner                                      0.1415            0.1538  ...
# Dependents                                   0.0237            0.0140  ...
# tenure                                       0.3603            0.3607  ...
# PhoneService                                -0.0523           -0.0712  ...
# MultipleLines                                0.2022            0.2011  ...
# OnlineSecurity                               0.2838            0.2754  ...
# OnlineBackup                                 1.0000            0.3035  ...
# DeviceProtection                             0.3035            1.0000  ...
# TechSupport                                  0.2942            0.3333  ...
# StreamingTV                                  0.2821            0.3909  ...
# StreamingMovies                              0.2745            0.4021  ...
# PaperlessBilling                             0.1267            0.1038  ...
# ChargesMonthly                               0.4418            0.4827  ...
# ChargesTotal                                 0.5101            0.5229  ...
# cuentas_diarias                              0.4418            0.4827  ...
# gender_female                                0.0138            0.0021  ...
# gender_male                                 -0.0138           -0.0021  ...
# InternetService_dsl                          0.1579            0.1463  ...
# InternetService_fiber optic                  0.1657            0.1760  ...
# InternetService_no                          -0.3816           -0.3808  ...
# Contract_month to month                     -0.1642           -0.2257  ...
# Contract_one year                            0.0837            0.1025  ...
# Contract_two year                            0.1114            0.1651  ...
# PaymentMethod_bank transfer automatic        0.0870            0.0831  ...
# PaymentMethod_credit card automatic          0.0908            0.1116  ...
# PaymentMethod_electronic check              -0.0004           -0.0034  ...
# PaymentMethod_mailed check                  -0.1742           -0.1874  ...
#
#                                        InternetService_dsl  \
# Churn                                              -0.1242
# SeniorCitizen                                      -0.1083
# Partner                                            -0.0009
# Dependents                                          0.0520
# tenure                                              0.0133
# PhoneService                                       -0.4524
# MultipleLines                                      -0.1999
# OnlineSecurity                                      0.3213
# OnlineBackup                                        0.1579
# DeviceProtection                                    0.1463
# TechSupport                                         0.3131
# StreamingTV                                         0.0163
# StreamingMovies                                     0.0257
# PaperlessBilling                                   -0.0631
# ChargesMonthly                                     -0.1602
# ChargesTotal                                       -0.0522
# cuentas_diarias                                    -0.1602
# gender_female                                      -0.0066
# gender_male                                         0.0066
# InternetService_dsl                                 1.0000
# InternetService_fiber optic                        -0.6410
# InternetService_no                                 -0.3806
# Contract_month to month                            -0.0655
# Contract_one year                                   0.0468
# Contract_two year                                   0.0317
# PaymentMethod_bank transfer automatic               0.0255
# PaymentMethod_credit card automatic                 0.0514
# PaymentMethod_electronic check                     -0.1044
# PaymentMethod_mailed check                          0.0419
#
#                                        InternetService_fiber optic  \
# Churn                                                       0.3080
# SeniorCitizen                                               0.2553
# Partner                                                     0.0003
# Dependents                                                 -0.1658
# tenure                                                      0.0197
# PhoneService                                                0.2900
# MultipleLines                                               0.3661
# OnlineSecurity                                             -0.0307
# OnlineBackup                                                0.1657
# DeviceProtection                                            0.1760
# TechSupport                                                -0.0205
# StreamingTV                                                 0.3293
# StreamingMovies                                             0.3229
# PaperlessBilling                                            0.3269
# ChargesMonthly                                              0.7871
# ChargesTotal                                                0.3608
# cuentas_diarias                                             0.7871
# gender_female                                               0.0113
# gender_male                                                -0.0113
# InternetService_dsl                                        -0.6410
# InternetService_fiber optic                                 1.0000
# InternetService_no                                         -0.4658
# Contract_month to month                                     0.2442
# Contract_one year                                          -0.0763
# Contract_two year                                          -0.2115
# PaymentMethod_bank transfer automatic                      -0.0226
# PaymentMethod_credit card automatic                        -0.0501
# PaymentMethod_electronic check                              0.3364
# PaymentMethod_mailed check                                 -0.3068
#
#                                        InternetService_no  \
# Churn                                             -0.2279
# SeniorCitizen                                     -0.1827
# Partner                                            0.0006
# Dependents                                         0.1398
# tenure                                            -0.0391
# PhoneService                                       0.1722
# MultipleLines                                     -0.2106
# OnlineSecurity                                    -0.3334
# OnlineBackup                                      -0.3816
# DeviceProtection                                  -0.3808
# TechSupport                                       -0.3363
# StreamingTV                                       -0.4156
# StreamingMovies                                   -0.4187
# PaperlessBilling                                  -0.3210
# ChargesMonthly                                    -0.7636
# ChargesTotal                                      -0.3749
# cuentas_diarias                                   -0.7636
# gender_female                                     -0.0060
# gender_male                                        0.0060
# InternetService_dsl                               -0.3806
# InternetService_fiber optic                       -0.4658
# InternetService_no                                 1.0000
# Contract_month to month                           -0.2186
# Contract_one year                                  0.0380
# Contract_two year                                  0.2183
# PaymentMethod_bank transfer automatic             -0.0021
# PaymentMethod_credit card automatic                0.0010
# PaymentMethod_electronic check                    -0.2849
# PaymentMethod_mailed check                         0.3214
#
#                                        Contract_month to month  \
# Churn                                                   0.4051
# SeniorCitizen                                           0.1384
# Partner                                                -0.2809
# Dependents                                             -0.2317
# tenure                                                 -0.6456
# PhoneService                                           -0.0007
# MultipleLines                                          -0.0882
# OnlineSecurity                                         -0.2467
# OnlineBackup                                           -0.1642
# DeviceProtection                                       -0.2257
# TechSupport                                            -0.2852
# StreamingTV                                            -0.1123
# StreamingMovies                                        -0.1166
# PaperlessBilling                                        0.1691
# ChargesMonthly                                          0.0602
# ChargesTotal                                           -0.4468
# cuentas_diarias                                         0.0602
# gender_female                                           0.0034
# gender_male                                            -0.0034
# InternetService_dsl                                    -0.0655
# InternetService_fiber optic                             0.2442
# InternetService_no                                     -0.2186
# Contract_month to month                                 1.0000
# Contract_one year                                      -0.5687
# Contract_two year                                      -0.6226
# PaymentMethod_bank transfer automatic                  -0.1797
# PaymentMethod_credit card automatic                    -0.2041
# PaymentMethod_electronic check                          0.3317
# PaymentMethod_mailed check                              0.0041
#
#                                        Contract_one year  Contract_two year  \
# Churn                                            -0.1778            -0.3023
# SeniorCitizen                                    -0.0463            -0.1170
# Partner                                           0.0828             0.2481
# Dependents                                        0.0684             0.2046
# tenure                                            0.2026             0.5585
# PhoneService                                     -0.0028             0.0035
# MultipleLines                                    -0.0038             0.1063
# OnlineSecurity                                    0.1002             0.1918
# OnlineBackup                                      0.0837             0.1114
# DeviceProtection                                  0.1025             0.1651
# TechSupport                                       0.0958             0.2408
# StreamingTV                                       0.0616             0.0720
# StreamingMovies                                   0.0649             0.0740
# PaperlessBilling                                 -0.0514            -0.1479
# ChargesMonthly                                    0.0049            -0.0747
# ChargesTotal                                      0.1706             0.3580
# cuentas_diarias                                   0.0049            -0.0747
# gender_female                                    -0.0080             0.0037
# gender_male                                       0.0080            -0.0037
# InternetService_dsl                               0.0468             0.0317
# InternetService_fiber optic                      -0.0763            -0.2115
# InternetService_no                                0.0380             0.2183
# Contract_month to month                          -0.5687            -0.6226
# Contract_one year                                 1.0000            -0.2895
# Contract_two year                                -0.2895             1.0000
# PaymentMethod_bank transfer automatic             0.0575             0.1545
# PaymentMethod_credit card automatic               0.0676             0.1733
# PaymentMethod_electronic check                   -0.1091            -0.2821
# PaymentMethod_mailed check                       -0.0001            -0.0047
#
#                                        PaymentMethod_bank transfer automatic  \
# Churn                                                                -0.1179
# SeniorCitizen                                                        -0.0162
# Partner                                                               0.1107
# Dependents                                                            0.0520
# tenure                                                                0.2435
# PhoneService                                                          0.0076
# MultipleLines                                                         0.0755
# OnlineSecurity                                                        0.0952
# OnlineBackup                                                          0.0870
# DeviceProtection                                                      0.0831
# TechSupport                                                           0.1013
# StreamingTV                                                           0.0463
# StreamingMovies                                                       0.0487
# PaperlessBilling                                                     -0.0163
# ChargesMonthly                                                        0.0428
# ChargesTotal                                                          0.1861
# cuentas_diarias                                                       0.0428
# gender_female                                                         0.0160
# gender_male                                                          -0.0160
# InternetService_dsl                                                   0.0255
# InternetService_fiber optic                                          -0.0226
# InternetService_no                                                   -0.0021
# Contract_month to month                                              -0.1797
# Contract_one year                                                     0.0575
# Contract_two year                                                     0.1545
# PaymentMethod_bank transfer automatic                                 1.0000
# PaymentMethod_credit card automatic                                  -0.2782
# PaymentMethod_electronic check                                       -0.3768
# PaymentMethod_mailed check                                           -0.2887
#
#                                        PaymentMethod_credit card automatic  \
# Churn                                                              -0.1343
# SeniorCitizen                                                      -0.0241
# Partner                                                             0.0820
# Dependents                                                          0.0603
# tenure                                                              0.2330
# PhoneService                                                       -0.0077
# MultipleLines                                                       0.0600
# OnlineSecurity                                                      0.1157
# OnlineBackup                                                        0.0908
# DeviceProtection                                                    0.1116
# TechSupport                                                         0.1173
# StreamingTV                                                         0.0404
# StreamingMovies                                                     0.0486
# PaperlessBilling                                                   -0.0136
# ChargesMonthly                                                      0.0306
# ChargesTotal                                                        0.1827
# cuentas_diarias                                                     0.0306
# gender_female                                                      -0.0012
# gender_male                                                         0.0012
# InternetService_dsl                                                 0.0514
# InternetService_fiber optic                                        -0.0501
# InternetService_no                                                  0.0010
# Contract_month to month                                            -0.2041
# Contract_one year                                                   0.0676
# Contract_two year                                                   0.1733
# PaymentMethod_bank transfer automatic                              -0.2782
# PaymentMethod_credit card automatic                                 1.0000
# PaymentMethod_electronic check                                     -0.3733
# PaymentMethod_mailed check                                         -0.2860
#
#                                        PaymentMethod_electronic check  \
# Churn                                                          0.3019
# SeniorCitizen                                                  0.1717
# Partner                                                       -0.0839
# Dependents                                                    -0.1506
# tenure                                                        -0.2084
# PhoneService                                                   0.0031
# MultipleLines                                                  0.0836
# OnlineSecurity                                                -0.1123
# OnlineBackup                                                  -0.0004
# DeviceProtection                                              -0.0034
# TechSupport                                                   -0.1148
# StreamingTV                                                    0.1446
# StreamingMovies                                                0.1380
# PaperlessBilling                                               0.2089
# ChargesMonthly                                                 0.2716
# ChargesTotal                                                  -0.0604
# cuentas_diarias                                                0.2716
# gender_female                                                 -0.0008
# gender_male                                                    0.0008
# InternetService_dsl                                           -0.1044
# InternetService_fiber optic                                    0.3364
# InternetService_no                                            -0.2849
# Contract_month to month                                        0.3317
# Contract_one year                                             -0.1091
# Contract_two year                                             -0.2821
# PaymentMethod_bank transfer automatic                         -0.3768
# PaymentMethod_credit card automatic                           -0.3733
# PaymentMethod_electronic check                                 1.0000
# PaymentMethod_mailed check                                    -0.3874
#
#                                        PaymentMethod_mailed check
# Churn                                                     -0.0917
# SeniorCitizen                                             -0.1535
# Partner                                                   -0.0951
# Dependents                                                 0.0591
# tenure                                                    -0.2339
# PhoneService                                              -0.0033
# MultipleLines                                             -0.2272
# OnlineSecurity                                            -0.0808
# OnlineBackup                                              -0.1742
# DeviceProtection                                          -0.1874
# TechSupport                                               -0.0855
# StreamingTV                                               -0.2477
# StreamingMovies                                           -0.2506
# PaperlessBilling                                          -0.2054
# ChargesMonthly                                            -0.3774
# ChargesTotal                                              -0.2947
# cuentas_diarias                                           -0.3774
# gender_female                                             -0.0137
# gender_male                                                0.0137
# InternetService_dsl                                        0.0419
# InternetService_fiber optic                               -0.3068
# InternetService_no                                         0.3214
# Contract_month to month                                    0.0041
# Contract_one year                                         -0.0001
# Contract_two year                                         -0.0047
# PaymentMethod_bank transfer automatic                     -0.2887
# PaymentMethod_credit card automatic                       -0.2860
# PaymentMethod_electronic check                            -0.3874
# PaymentMethod_mailed check                                 1.0000
#
# [29 rows x 29 columns]

# %%
# vamos a ordenar la primera columna
correlacion = df.corr()['Churn'].sort_values(ascending=False).round(4)
correlacion
# Out:
# Churn                                    1.0000
# Contract_month to month                  0.4051
# InternetService_fiber optic              0.3080
# PaymentMethod_electronic check           0.3019
# ChargesMonthly                           0.1934
# cuentas_diarias                          0.1934
# PaperlessBilling                         0.1918
# SeniorCitizen                            0.1509
# StreamingTV                              0.0632
# StreamingMovies                          0.0614
# MultipleLines                            0.0401
# PhoneService                             0.0119
# gender_female                            0.0086
# gender_male                             -0.0086
# DeviceProtection                        -0.0662
# OnlineBackup                            -0.0823
# PaymentMethod_mailed check              -0.0917
# PaymentMethod_bank transfer automatic   -0.1179
# InternetService_dsl                     -0.1242
# PaymentMethod_credit card automatic     -0.1343
# Partner                                 -0.1504
# Dependents                              -0.1642
# TechSupport                             -0.1647
# OnlineSecurity                          -0.1712
# Contract_one year                       -0.1778
# ChargesTotal                            -0.1995
# InternetService_no                      -0.2279
# Contract_two year                       -0.3023
# tenure                                  -0.3522
# Name: Churn, dtype: float64

# %% [markdown]
# Sí comparamos los datos correlacionados con el abandono por las variables, nos damos cuenta que no coinciden. Un ejemplo de ello es el streaming de Tv, la distribución del Churn por streaming Tv es de 30% y cuando vemos esta variable correlacionado con el abandono, nos indica que las variables no están relacionados ni directa (0.06) ni indirectamente.

# %%
from tabulate import tabulate

# %%
tabla = [['Variable','Correlación','Observaciones'],
    ['Contract_month to month',0.4051,'El contrato mes a mes tiene una alta incidencia en el abandono. Menor permananencia mayor abandono'],
         ['InternetService_fiber optic',0.3080,'El servicio de Fibra óptica esta muy relacionado con el abandono , puede ser por fallas'],
         ['PaymentMethod_electronic check',0.3019,'Pago electrónico alta tasa de abandono, mejorar la experiencia de pago o promocionar otras alternativas de pago'],
         ['ChargesMonthly',0.1934,'Los pagos mensuales influyen directamente en el abandono, ver promosiones u ofertas'],
         ['PaperlessBilling',0.1918,'Los clientes que reciben factura en línea tienen alto abandono, implementar servicio de correo en papel'],
         ['']]
formato_tabla = 'plain'
crear_tabla = tabulate(tabla, headers="firstrow", tablefmt=formato_tabla)
contenido_celda = f"Tabla de variables que explica el abandono de clientes:\n{crear_tabla}\n."
print(contenido_celda)
# Out:
# Tabla de variables que explica el abandono de clientes:
# Variable                          Correlación  Observaciones
# Contract_month to month                0.4051  El contrato mes a mes tiene una alta incidencia en el abandono. Menor permananencia mayor abandono
# InternetService_fiber optic            0.308   El servicio de Fibra óptica esta muy relacionado con el abandono , puede ser por fallas
# PaymentMethod_electronic check         0.3019  Pago electrónico alta tasa de abandono, mejorar la experiencia de pago o promocionar otras alternativas de pago
# ChargesMonthly                         0.1934  Los pagos mensuales influyen directamente en el abandono, ver promosiones u ofertas
# PaperlessBilling                       0.1918  Los clientes que reciben factura en línea tienen alto abandono, implementar servicio de correo en papel
#
# .

# %% [markdown]
# ##**Separación de las Variables X e y**

# %%
#Variable Independiente o explicativa
X = df.drop('Churn',axis=1)

# Variable Dependiente o variable Objetivo
y = df['Churn']

# %% [markdown]
# ##**Separando los Datos en Entrenamiento y Test**

# %%
from sklearn.model_selection import train_test_split

# %%
X,X_test,y,y_test = train_test_split(X,y,test_size=0.30,stratify=y,random_state=42)
X_train,X_val,y_train,y_val = train_test_split(X,y,random_state=42,stratify=y)# el 25% de los datos de train son para validación

# %% [markdown]
# ##**Balanceo de Datos con Smote**

# %% [markdown]
# Los datos no están muy desbalanceados por lo que no utizaremos está técnica

# %% [markdown]
# ##**Modelo Decision Tree Classifier**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
modelo_DT = DecisionTreeClassifier(max_depth=10)
modelo_DT.fit(X_train,y_train)
print(f'La exactitud del modelo con el conjunto de entrenamiento es de: {modelo_DT.score(X_train,y_train)}')
print(f'La exactitud del modelo con el conjunto de validación es de: {modelo_DT.score(X_val,y_val)}')
# Out:
# La exactitud del modelo con el conjunto de entrenamiento es de: 0.8934271030565323
# La exactitud del modelo con el conjunto de validación es de: 0.7599351175993512

# %% [markdown]
# ###**Evaluando el Modelo**

# %% [markdown]
# ####**Matriz de Confusion**

# %%
from sklearn.metrics import confusion_matrix

# %%
y_previsto = modelo_DT.predict(X_val)
matriz_confusion = confusion_matrix(y_val,y_previsto) #compara los valores reales (val) con los previstos
print(matriz_confusion)
# Out:
# [[787 119]
#  [177 150]]

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
visualizacion = ConfusionMatrixDisplay(confusion_matrix = matriz_confusion,display_labels=['Permanece','Abandono'])
visualizacion.plot();

# %% [markdown]
# El modelo Decission Tree Classifier evaluado con la matriz de confusion
#
# La predicción  es que permanecen y el cliente realmente abandona es de 183
#
# La prediicion es que abandona y el cliente realmente abandona es de 144
#
# La prediccion es que permanece y el cliente realmente permanece es de 792
#
# La prediccion es que abandona y el cliente realmente permanece es 114

# %% [markdown]
# ####**Metricas de Evaluación**

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score,f1_score

# %%
print(f'La precision del modelo es :{precision_score(y_val,y_previsto)}')
print(f'La sensibilidad (recall) del modelo es :{recall_score(y_val,y_previsto)}')
print(f'La exactitud (accuracy) del modelo es :{accuracy_score(y_val,y_previsto)}')
print(f'El F1-score del modelo es :{f1_score(y_val,y_previsto)}')
# Out:
# La precision del modelo es :0.5576208178438662
# La sensibilidad (recall) del modelo es :0.45871559633027525
# La exactitud (accuracy) del modelo es :0.7599351175993512
# El F1-score del modelo es :0.5033557046979866

# %% [markdown]
# #####**Curva ROC**

# %%
from sklearn.metrics import RocCurveDisplay

# %%
RocCurveDisplay.from_predictions(y_val,y_previsto,name='Árbol de Decisión');

# %%
from sklearn.metrics import roc_auc_score

# %%
print(f'El área bajo la curva ROC del modelo es: {roc_auc_score(y_val,y_previsto)}')
# Out:
# El área bajo la curva ROC del modelo es: 0.6636845089819147

# %% [markdown]
# #####**Curva de Precision por sensibilidad**

# %%
from sklearn.metrics import PrecisionRecallDisplay

# %%
PrecisionRecallDisplay.from_predictions(y_val,y_previsto,name='Árbol de Decisión');

# %%
from sklearn.metrics import average_precision_score

# %%
print(f'El score promedio de precision vs recall es : {average_precision_score(y_val,y_previsto)}')
# Out:
# El score promedio de precision vs recall es : 0.399341677418948

# %% [markdown]
# #####**Informe de Metricas**

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_val,y_previsto))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84       906
#            1       0.56      0.46      0.50       327
#
#     accuracy                           0.76      1233
#    macro avg       0.69      0.66      0.67      1233
# weighted avg       0.75      0.76      0.75      1233

# %% [markdown]
# #####**Importancia de las Variables**

# %%
importancia = modelo_DT.feature_importances_
importancia
# Out:
# array([0.02257042, 0.00681535, 0.01820698, 0.13282727, 0.00972618,
#        0.00718741, 0.01513071, 0.0120837 , 0.0083689 , 0.01474717,
#        0.00220038, 0.00249988, 0.02004999, 0.10466694, 0.13143551,
#        0.0620283 , 0.01329174, 0.00851923, 0.00397271, 0.06950812,
#        0.01225594, 0.27121313, 0.00231468, 0.        , 0.00614093,
#        0.01421077, 0.02369865, 0.00432899])

# %%
Variables_importantes = pd.DataFrame({'Variables': X.columns,'Importancia':(importancia*100).round(2)})
Variables_importantes.sort_values('Importancia',ascending=False)
# Out:
#                                 Variables  Importancia
# 21                Contract_month to month        27.12
# 3                                  tenure        13.28
# 14                           ChargesTotal        13.14
# 13                         ChargesMonthly        10.47
# 19            InternetService_fiber optic         6.95
# 15                        cuentas_diarias         6.20
# 26         PaymentMethod_electronic check         2.37
# 0                           SeniorCitizen         2.26
# 12                       PaperlessBilling         2.00
# 2                              Dependents         1.82
# 6                          OnlineSecurity         1.51
# 9                             TechSupport         1.47
# 25    PaymentMethod_credit card automatic         1.42
# 16                          gender_female         1.33
# 20                     InternetService_no         1.23
# 7                            OnlineBackup         1.21
# 4                            PhoneService         0.97
# 17                            gender_male         0.85
# 8                        DeviceProtection         0.84
# 5                           MultipleLines         0.72
# 1                                 Partner         0.68
# 24  PaymentMethod_bank transfer automatic         0.61
# 27             PaymentMethod_mailed check         0.43
# 18                    InternetService_dsl         0.40
# 11                        StreamingMovies         0.25
# 22                      Contract_one year         0.23
# 10                            StreamingTV         0.22
# 23                      Contract_two year         0.00

# %% [markdown]
# ###**Probando el modelo Decission Tree Classifier**

# %%
y_previsto_DT_test = modelo_DT.predict(X_test)

# %%
print(classification_report(y_test,y_previsto_DT_test))
ConfusionMatrixDisplay.from_predictions(y_test,y_previsto_DT_test,display_labels=['Permanece','Abandono']);
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83      1552
#            1       0.52      0.45      0.49       561
#
#     accuracy                           0.74      2113
#    macro avg       0.67      0.65      0.66      2113
# weighted avg       0.73      0.74      0.74      2113

# %% [markdown]
# ##**Modelo Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
modelo_RF = RandomForestClassifier(max_depth=10)

# %%
modelo_RF.fit(X_train,y_train)
print(f'precision del modelo con el conjunto de entrenamiento: {modelo_RF.score(X_train,y_train)}')
print(f'precision del modelo con el conjunto de validación: {modelo_RF.score(X_val,y_val)}')
# Out:
# precision del modelo con el conjunto de entrenamiento: 0.9010008114687584
# precision del modelo con el conjunto de validación: 0.8118410381184104

# %% [markdown]
# ###**Evaluando El Modelo Random Forest**

# %% [markdown]
# ####**Matriz de Confusión**

# %%
y_previsto = modelo_RF.predict(X_val)

# %%
matriz_confusion = confusion_matrix(y_val,y_previsto)
visualizacion = ConfusionMatrixDisplay(confusion_matrix = matriz_confusion,display_labels=['Permanece','Abandono'])
visualizacion.plot();

# %% [markdown]
# El modelo Random Forest Classifier evaluado con la matriz de confusion
#
# La predicción  es que permanecen y el cliente realmente abandona es de 141
#
# La prediccion es que abandona y el cliente realmente abandona es de 186
#
# La prediccion es que permanece y el cliente realmente permanece es de 818
#
# La prediccion es que abandona y el cliente realmente permanece es 88

# %% [markdown]
# ####**Metricas de Evaluación**

# %%
print(f'La precision del modelo es :{precision_score(y_val,y_previsto)}')
print(f'La sensibilidad (recall) del modelo es :{recall_score(y_val,y_previsto)}')
print(f'La exactitud (accuracy) del modelo es :{accuracy_score(y_val,y_previsto)}')
print(f'El F1-score del modelo es :{f1_score(y_val,y_previsto)}')
# Out:
# La precision del modelo es :0.6877470355731226
# La sensibilidad (recall) del modelo es :0.5321100917431193
# La exactitud (accuracy) del modelo es :0.8118410381184104
# El F1-score del modelo es :0.6

# %% [markdown]
# #####**Curva ROC**

# %%
RocCurveDisplay.from_predictions(y_val,y_previsto,name='Random Forest');

# %%
print(f'El área bajo la curva ROC del modelo es: {roc_auc_score(y_val,y_previsto)}')
# Out:
# El área bajo la curva ROC del modelo es: 0.7224568118759747

# %% [markdown]
# #####**Curva de Precision por sensibilidad**

# %%
PrecisionRecallDisplay.from_predictions(y_val,y_previsto,name='Random Forest');

# %%
print(f'El score promedio de precision vs recall es : {average_precision_score(y_val,y_previsto)}')
# Out:
# El score promedio de precision vs recall es : 0.4900447294357485

# %% [markdown]
# #####**Informe de Métricas**

# %%
print(classification_report(y_val,y_previsto))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.88       906
#            1       0.69      0.53      0.60       327
#
#     accuracy                           0.81      1233
#    macro avg       0.77      0.72      0.74      1233
# weighted avg       0.80      0.81      0.80      1233

# %% [markdown]
# #####**Importancia de las Variables**

# %%
importancia = modelo_RF.feature_importances_
importancia
# Out:
# array([0.01612439, 0.01521926, 0.01456375, 0.14437059, 0.00640068,
#        0.01226967, 0.02056514, 0.01318331, 0.0109437 , 0.02203361,
#        0.01107058, 0.01024444, 0.024263  , 0.10602955, 0.13849467,
#        0.10467616, 0.01318449, 0.01273405, 0.01426139, 0.03702682,
#        0.01587618, 0.11027836, 0.01528174, 0.03447989, 0.00920842,
#        0.00939715, 0.04875763, 0.00906139])

# %%
Variables_importantes = pd.DataFrame({'Variables': X.columns,'Importancia':(importancia*100).round(2)})
Variables_importantes.sort_values('Importancia',ascending=False)
# Out:
#                                 Variables  Importancia
# 3                                  tenure        14.44
# 14                           ChargesTotal        13.85
# 21                Contract_month to month        11.03
# 13                         ChargesMonthly        10.60
# 15                        cuentas_diarias        10.47
# 26         PaymentMethod_electronic check         4.88
# 19            InternetService_fiber optic         3.70
# 23                      Contract_two year         3.45
# 12                       PaperlessBilling         2.43
# 9                             TechSupport         2.20
# 6                          OnlineSecurity         2.06
# 0                           SeniorCitizen         1.61
# 20                     InternetService_no         1.59
# 22                      Contract_one year         1.53
# 1                                 Partner         1.52
# 2                              Dependents         1.46
# 18                    InternetService_dsl         1.43
# 7                            OnlineBackup         1.32
# 16                          gender_female         1.32
# 17                            gender_male         1.27
# 5                           MultipleLines         1.23
# 10                            StreamingTV         1.11
# 8                        DeviceProtection         1.09
# 11                        StreamingMovies         1.02
# 25    PaymentMethod_credit card automatic         0.94
# 24  PaymentMethod_bank transfer automatic         0.92
# 27             PaymentMethod_mailed check         0.91
# 4                            PhoneService         0.64

# %% [markdown]
# ###**Probando el modelo Random Forest**

# %%
y_previsto_RF_test = modelo_RF.predict(X_test)

# %%
print(classification_report(y_test,y_previsto_RF_test))
ConfusionMatrixDisplay.from_predictions(y_test,y_previsto_RF_test,display_labels=['Permanece','Abandono']);
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86      1552
#            1       0.63      0.52      0.57       561
#
#     accuracy                           0.79      2113
#    macro avg       0.73      0.71      0.72      2113
# weighted avg       0.78      0.79      0.78      2113

# %% [markdown]
# ##**Informe Final**

# %% [markdown]
# Al hacer los análisis gráficos de la distribución de las variables y la correlación de datos concluimos que las variables que más inciden en el abandono son:
#
# Varaibles que explican en Abandono de clientes
#
# *   El contrato mes a mes es una de las principales variables que inciden en el abandono de clientes, ya que estos no tienen compromisos con la empresa, se ugiere una campaña de fidelización, proponiendo contratos a largo plazo, unido a  mejoras en los descuentos a medidaque aumenten los servicios y el tiempo de los contratos
# *   Metodo de pago Electronic Check, es otra de las principales variables que explican el abandonode clientes, se sugiere una campaña de de pago por otros medios y ó  mejorar la experiencia de pago con este medio haciendola más simple de usar
# *   Servicio de Internet por Fibra óptica, este servicio tiene una alta tasa de abandono, tal vez esto se explica con problemas técnicos en el servicio. Se recomienda mejorar la calidad del servicio.
# *   Cargos mensuales altos, estos también inciden en el alto abandoni de clientes, se sugiere una política de descuentos fomentando la integración de servicios, a medida que el cliente cuente con más servicios, mayor descuento. Tambien pude crearse una plataforma comercial y técnica exclusiva para responder rapidamente a los clientes que varios servicios contratadoy y que paguen altas cifras mensuales.
#
# Variables que ayudan a prevenir la probabilidad de abandono.
#
#
# *   A mayor tiempo de contrato, mayor es la probabilidadde mantener al cliente en la empresa, por lo que tener una política de contratos a largo plazo es fundamental.
# *   Tener contratos de soporte técnicoayuda a mantener a clientes cautivos, ya que mejora la experiencia de servicio.
#
#
# *   Tener seguridad On Line ayuda a mantener al cliente debido a la experiencia de resguardar sus datos y bienes.
# *   El pago automático a través de tarjeta de crédito o transferencia bancaria ayuda a mantener al cliente, se debeb incentivar el pago a través de estos medios
#
# Modelos de Aprendizaje automático
#
# La elección de los modelos de árbol en vez de los modelos de Regresión lineal se debe a que los primeros son menos sensibles a la escala de los datos, además que nuestra variable objetivo solo tenía 2 valores posibles, 0 o 1 , por lo cual ajustar una línea recta a los modelos de regresión lineal es imposible ya que no hay dispersión de los datos y no podriamos medir con las métricas de r2, MAE entre otros parámetros, ya que no podriamos medir la distancia de los datos a la recta. Así que en mi opinión los modelos de árbol se ajustan de mejor manera a este problema.
# Se eligieron los modelos Decision Tree Classsifier y Random Forest. Al comparar los resultados con las metricas precision, recall,F1 score y accuracy, tanto con los datos de validación como con los datos de prueba pudimos observar que ambos modelos son consisten y no tienen una diferencia notable
#
# Resultados del modelo Decision Tree Classifier con los datos de validación
#
#                 precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84       906
#            1       0.56      0.46      0.50       327
#
#     accuracy                           0.76      1233
#
#
#
# Resultados del modelo Decision Tree Classifier con los datos de Prueba
#
#                 precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83      1552
#            1       0.52      0.45      0.49       561
#
#     accuracy                           0.74      2113
#
#
# Como podemos observar en ambos cuadros, con el modelo Decision Tree Classifier los resultados con los datos de validación y con los datos de prueba son muy similares por lo que concluimos que el modelo está pronosticando bien los resultados y no se observa sobre o bajo ajuste
#
#
# Resultados del modelo Random Forest con los datos de validación
#
#                 precision    recall  f1-score   support
#
#            0       0.84      0.91      0.88       906
#            1       0.69      0.53      0.60       327
#
#     accuracy                           0.81      1233
#
# Resultados del modelo Random Forest con los datos de prueba
#
#                 precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86      1552
#            1       0.63      0.52      0.57       561
#
#     accuracy                           0.79      2113
#
#
# Al comparar los resultados del modelo Random Forest con los datos de validación y con los datos de prueba, podemos observar que no hay grandes diferencias en los datos previstos por lo que concluimos que nuestro modelo está pronosticando bien.
#
# Al comparar ambos modelos elegidos, podemos concluir que Random Forest tiene mejores valores en las metricas precision, recall y F1 en predecir el abandono. En predecir que cliente se queda en la empresa ambos modelos son muy similares. Por lo cual el modelo elegido será Randon Forest
